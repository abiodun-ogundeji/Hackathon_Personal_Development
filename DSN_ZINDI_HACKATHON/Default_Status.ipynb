# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset_train=pd.read_csv('file:///Users/mac/Downloads/Train.csv')
dataset_test=pd.read_csv('file:///Users/mac/Downloads/Test.csv')

# %%
dataset_train.shape
# Out:
# (56000, 52)

# %%
dataset_test.shape
# Out:
# (24000, 51)

# %%
dataset_train.head()
# Out:
#    form_field1  form_field2  form_field3  form_field4  form_field5  \
# 0       3436.0      0.28505       1.6560          0.0        0.000
# 1       3456.0      0.67400       0.2342          0.0        0.000
# 2       3276.0      0.53845       3.1510          0.0        6.282
# 3       3372.0      0.17005       0.5050          0.0        0.000
# 4       3370.0      0.77270       1.1010          0.0        0.000
#
#    form_field6  form_field7  form_field8  form_field9  form_field10  ...  \
# 0          0.0   10689720.0     252072.0    4272776.0    11333126.0  ...
# 1          0.0     898979.0     497531.0    9073814.0     2533168.0  ...
# 2          0.0     956940.0          0.0     192944.0     1079864.0  ...
# 3     192166.0    3044703.0     385499.0    3986472.0     3621979.0  ...
# 4       1556.0     214728.0     214728.0    1284089.0      361770.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# ...

# %%
##Missing Values: Check where there are missing values and fix them appropriately
total = dataset_train.isnull().sum().sort_values(ascending=False)
percent = (dataset_train.isnull().sum()/dataset_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(52)
# Out:
#                 Total  Percent
# default_status      0      0.0
# form_field50        0      0.0
# form_field23        0      0.0
# form_field22        0      0.0
# form_field21        0      0.0
# form_field20        0      0.0
# form_field19        0      0.0
# form_field18        0      0.0
# form_field17        0      0.0
# form_field16        0      0.0
# form_field15        0      0.0
# form_field14        0      0.0
# form_field13        0      0.0
# form_field12        0      0.0
# form_field11        0      0.0
# form_field10        0      0.0
# form_field9         0      0.0
# form_field8         0      0.0
# form_field7         0      0.0
# form_field6         0      0.0
# form_field5         0      0.0
# form_field4         0      0.0
# form_field3         0      0.0
# form_field2         0      0.0
# form_field1         0      0.0
# form_field24        0      0.0
# form_field25        0      0.0
# form_field26        0      0.0
# form_field39        0      0.0
# ...

# %%
dataset_train['form_field1'] = dataset_train['form_field1'].fillna(dataset_train['form_field1'].dropna().mode().values[0])
dataset_train['form_field2'] = dataset_train['form_field2'].fillna(dataset_train['form_field2'].dropna().mode().values[0])
dataset_train['form_field3'] = dataset_train['form_field3'].fillna(dataset_train['form_field3'].dropna().mode().values[0])
dataset_train['form_field4'] = dataset_train['form_field4'].fillna(dataset_train['form_field4'].dropna().mode().values[0])
dataset_train['form_field5'] = dataset_train['form_field5'].fillna(dataset_train['form_field5'].dropna().mode().values[0])
dataset_train['form_field6'] = dataset_train['form_field6'].fillna(dataset_train['form_field6'].dropna().mode().values[0])
dataset_train['form_field7'] = dataset_train['form_field7'].fillna(dataset_train['form_field7'].dropna().mode().values[0])
dataset_train['form_field8'] = dataset_train['form_field8'].fillna(dataset_train['form_field8'].dropna().mode().values[0])
dataset_train['form_field9'] = dataset_train['form_field9'].fillna(dataset_train['form_field9'].dropna().mode().values[0])
dataset_train['form_field10'] = dataset_train['form_field10'].fillna(dataset_train['form_field10'].dropna().mode().values[0])
dataset_train['form_field11'] = dataset_train['form_field11'].fillna(dataset_train['form_field11'].dropna().mode().values[0])
dataset_train['form_field12'] = dataset_train['form_field12'].fillna(dataset_train['form_field12'].dropna().mode().values[0])
dataset_train['form_field13'] = dataset_train['form_field13'].fillna(dataset_train['form_field13'].dropna().mode().values[0])
dataset_train['form_field15'] = dataset_train['form_field15'].fillna(dataset_train['form_field15'].dropna().mode().values[0])
dataset_train['form_field16'] = dataset_train['form_field16'].fillna(dataset_train['form_field16'].dropna().mode().values[0])
dataset_train['form_field17'] = dataset_train['form_field17'].fillna(dataset_train['form_field17'].dropna().mode().values[0])
dataset_train['form_field18'] = dataset_train['form_field18'].fillna(dataset_train['form_field18'].dropna().mode().values[0])
dataset_train['form_field19'] = dataset_train['form_field19'].fillna(dataset_train['form_field19'].dropna().mode().values[0])
dataset_train['form_field20'] = dataset_train['form_field20'].fillna(dataset_train['form_field20'].dropna().mode().values[0])
dataset_train['form_field21'] = dataset_train['form_field21'].fillna(dataset_train['form_field21'].dropna().mode().values[0])
dataset_train['form_field22'] = dataset_train['form_field22'].fillna(dataset_train['form_field22'].dropna().mode().values[0])
dataset_train['form_field23'] = dataset_train['form_field23'].fillna(dataset_train['form_field23'].dropna().mode().values[0])
dataset_train['form_field24'] = dataset_train['form_field24'].fillna(dataset_train['form_field24'].dropna().mode().values[0])
dataset_train['form_field25'] = dataset_train['form_field26'].fillna(dataset_train['form_field25'].dropna().mode().values[0])
dataset_train['form_field26'] = dataset_train['form_field26'].fillna(dataset_train['form_field26'].dropna().mode().values[0])
dataset_train['form_field27'] = dataset_train['form_field27'].fillna(dataset_train['form_field27'].dropna().mode().values[0])
dataset_train['form_field28'] = dataset_train['form_field28'].fillna(dataset_train['form_field28'].dropna().mode().values[0])
dataset_train['form_field29'] = dataset_train['form_field29'].fillna(dataset_train['form_field29'].dropna().mode().values[0])
dataset_train['form_field30'] = dataset_train['form_field30'].fillna(dataset_train['form_field30'].dropna().mode().values[0])
dataset_train['form_field31'] = dataset_train['form_field31'].fillna(dataset_train['form_field31'].dropna().mode().values[0])
dataset_train['form_field32'] = dataset_train['form_field32'].fillna(dataset_train['form_field32'].dropna().mode().values[0])
dataset_train['form_field33'] = dataset_train['form_field33'].fillna(dataset_train['form_field33'].dropna().mode().values[0])
dataset_train['form_field34'] = dataset_train['form_field34'].fillna(dataset_train['form_field34'].dropna().mode().values[0])
dataset_train['form_field35'] = dataset_train['form_field35'].fillna(dataset_train['form_field35'].dropna().mode().values[0])
dataset_train['form_field36'] = dataset_train['form_field36'].fillna(dataset_train['form_field36'].dropna().mode().values[0])
dataset_train['form_field37'] = dataset_train['form_field37'].fillna(dataset_train['form_field37'].dropna().mode().values[0])
dataset_train['form_field38'] = dataset_train['form_field38'].fillna(dataset_train['form_field38'].dropna().mode().values[0])
dataset_train['form_field39'] = dataset_train['form_field39'].fillna(dataset_train['form_field39'].dropna().mode().values[0])
dataset_train['form_field40'] = dataset_train['form_field40'].fillna(dataset_train['form_field40'].dropna().mode().values[0])
dataset_train['form_field41'] = dataset_train['form_field41'].fillna(dataset_train['form_field41'].dropna().mode().values[0])
dataset_train['form_field42'] = dataset_train['form_field42'].fillna(dataset_train['form_field42'].dropna().mode().values[0])
dataset_train['form_field43'] = dataset_train['form_field43'].fillna(dataset_train['form_field43'].dropna().mode().values[0])
dataset_train['form_field44'] = dataset_train['form_field44'].fillna(dataset_train['form_field44'].dropna().mode().values[0])
dataset_train['form_field45'] = dataset_train['form_field45'].fillna(dataset_train['form_field45'].dropna().mode().values[0])
dataset_train['form_field46'] = dataset_train['form_field46'].fillna(dataset_train['form_field46'].dropna().mode().values[0])
dataset_train['form_field48'] = dataset_train['form_field48'].fillna(dataset_train['form_field48'].dropna().mode().values[0])
dataset_train['form_field49'] = dataset_train['form_field49'].fillna(dataset_train['form_field49'].dropna().mode().values[0])
dataset_train['form_field50'] = dataset_train['form_field50'].fillna(dataset_train['form_field50'].dropna().mode().values[0])

# %%
##Missing Values: Check where there are missing values and fix them appropriately
total = dataset_train.isnull().sum().sort_values(ascending=False)
percent = (dataset_train.isnull().sum()/dataset_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(52)
# Out:
#                 Total  Percent
# default_status      0      0.0
# form_field50        0      0.0
# form_field23        0      0.0
# form_field22        0      0.0
# form_field21        0      0.0
# form_field20        0      0.0
# form_field19        0      0.0
# form_field18        0      0.0
# form_field17        0      0.0
# form_field16        0      0.0
# form_field15        0      0.0
# form_field14        0      0.0
# form_field13        0      0.0
# form_field12        0      0.0
# form_field11        0      0.0
# form_field10        0      0.0
# form_field9         0      0.0
# form_field8         0      0.0
# form_field7         0      0.0
# form_field6         0      0.0
# form_field5         0      0.0
# form_field4         0      0.0
# form_field3         0      0.0
# form_field2         0      0.0
# form_field1         0      0.0
# form_field24        0      0.0
# form_field25        0      0.0
# form_field26        0      0.0
# form_field39        0      0.0
# ...

# %%
##Missing Values: Check where there are missing values and fix them appropriately
total = dataset_test.isnull().sum().sort_values(ascending=False)
percent = (dataset_test.isnull().sum()/dataset_test.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(51)
# Out:
#               Total   Percent
# form_field40  18828  0.784500
# form_field31  16810  0.700417
# form_field41  16349  0.681208
# form_field45  13538  0.564083
# form_field11  13398  0.558250
# form_field23  12125  0.505208
# form_field30  10908  0.454500
# form_field35   9866  0.411083
# form_field15   9592  0.399667
# form_field48   8922  0.371750
# form_field22   8724  0.363500
# form_field46   6885  0.286875
# form_field21   6707  0.279458
# form_field24   5605  0.233542
# form_field8    5604  0.233500
# form_field6    5604  0.233500
# form_field16   5474  0.228083
# form_field50   4797  0.199875
# form_field17   4695  0.195625
# form_field18   4369  0.182042
# form_field12   4183  0.174292
# form_field27   3910  0.162917
# form_field9    3400  0.141667
# form_field26   3172  0.132167
# form_field13   2463  0.102625
# form_field44   2362  0.098417
# form_field25   2256  0.094000
# form_field32   2256  0.094000
# form_field37   2256  0.094000
# form_field7    2231  0.092958
# ...

# %%
dataset_test['form_field1'] = dataset_test['form_field1'].fillna(dataset_test['form_field1'].dropna().mode().values[0])
dataset_test['form_field2'] = dataset_test['form_field2'].fillna(dataset_test['form_field2'].dropna().mode().values[0])
dataset_test['form_field3'] = dataset_test['form_field3'].fillna(dataset_test['form_field3'].dropna().mode().values[0])
dataset_test['form_field4'] = dataset_test['form_field4'].fillna(dataset_test['form_field4'].dropna().mode().values[0])
dataset_test['form_field5'] = dataset_test['form_field5'].fillna(dataset_test['form_field5'].dropna().mode().values[0])
dataset_test['form_field6'] = dataset_test['form_field6'].fillna(dataset_test['form_field6'].dropna().mode().values[0])
dataset_test['form_field7'] = dataset_test['form_field7'].fillna(dataset_test['form_field7'].dropna().mode().values[0])
dataset_test['form_field8'] = dataset_test['form_field8'].fillna(dataset_test['form_field8'].dropna().mode().values[0])
dataset_test['form_field9'] = dataset_test['form_field9'].fillna(dataset_test['form_field9'].dropna().mode().values[0])
dataset_test['form_field10'] = dataset_test['form_field10'].fillna(dataset_test['form_field10'].dropna().mode().values[0])
dataset_test['form_field11'] = dataset_test['form_field11'].fillna(dataset_test['form_field11'].dropna().mode().values[0])
dataset_test['form_field12'] = dataset_test['form_field12'].fillna(dataset_test['form_field12'].dropna().mode().values[0])
dataset_test['form_field13'] = dataset_test['form_field13'].fillna(dataset_test['form_field13'].dropna().mode().values[0])
dataset_test['form_field15'] = dataset_test['form_field15'].fillna(dataset_test['form_field15'].dropna().mode().values[0])
dataset_test['form_field16'] = dataset_test['form_field16'].fillna(dataset_test['form_field16'].dropna().mode().values[0])
dataset_test['form_field17'] = dataset_test['form_field17'].fillna(dataset_test['form_field17'].dropna().mode().values[0])
dataset_test['form_field18'] = dataset_test['form_field18'].fillna(dataset_test['form_field18'].dropna().mode().values[0])
dataset_test['form_field20'] = dataset_test['form_field20'].fillna(dataset_test['form_field20'].dropna().mode().values[0])
dataset_test['form_field21'] = dataset_test['form_field21'].fillna(dataset_test['form_field21'].dropna().mode().values[0])
dataset_test['form_field22'] = dataset_test['form_field22'].fillna(dataset_test['form_field22'].dropna().mode().values[0])
dataset_test['form_field23'] = dataset_test['form_field23'].fillna(dataset_test['form_field23'].dropna().mode().values[0])
dataset_test['form_field24'] = dataset_test['form_field24'].fillna(dataset_test['form_field24'].dropna().mode().values[0])
dataset_test['form_field25'] = dataset_test['form_field26'].fillna(dataset_test['form_field25'].dropna().mode().values[0])
dataset_test['form_field26'] = dataset_test['form_field26'].fillna(dataset_test['form_field26'].dropna().mode().values[0])
dataset_test['form_field27'] = dataset_test['form_field27'].fillna(dataset_test['form_field27'].dropna().mode().values[0])
dataset_test['form_field28'] = dataset_test['form_field28'].fillna(dataset_test['form_field28'].dropna().mode().values[0])
dataset_test['form_field29'] = dataset_test['form_field29'].fillna(dataset_test['form_field29'].dropna().mode().values[0])
dataset_test['form_field30'] = dataset_test['form_field30'].fillna(dataset_test['form_field30'].dropna().mode().values[0])
dataset_test['form_field31'] = dataset_test['form_field31'].fillna(dataset_test['form_field31'].dropna().mode().values[0])
dataset_test['form_field32'] = dataset_test['form_field32'].fillna(dataset_test['form_field32'].dropna().mode().values[0])
dataset_test['form_field33'] = dataset_test['form_field33'].fillna(dataset_test['form_field33'].dropna().mode().values[0])
dataset_test['form_field34'] = dataset_test['form_field34'].fillna(dataset_test['form_field34'].dropna().mode().values[0])
dataset_test['form_field35'] = dataset_test['form_field35'].fillna(dataset_test['form_field35'].dropna().mode().values[0])
dataset_test['form_field36'] = dataset_test['form_field36'].fillna(dataset_test['form_field36'].dropna().mode().values[0])
dataset_test['form_field37'] = dataset_test['form_field37'].fillna(dataset_test['form_field37'].dropna().mode().values[0])
dataset_test['form_field38'] = dataset_test['form_field38'].fillna(dataset_test['form_field38'].dropna().mode().values[0])
dataset_test['form_field39'] = dataset_test['form_field39'].fillna(dataset_test['form_field39'].dropna().mode().values[0])
dataset_test['form_field40'] = dataset_test['form_field40'].fillna(dataset_test['form_field40'].dropna().mode().values[0])
dataset_test['form_field41'] = dataset_test['form_field41'].fillna(dataset_test['form_field41'].dropna().mode().values[0])
dataset_test['form_field42'] = dataset_test['form_field42'].fillna(dataset_test['form_field42'].dropna().mode().values[0])
dataset_test['form_field43'] = dataset_test['form_field43'].fillna(dataset_test['form_field43'].dropna().mode().values[0])
dataset_test['form_field44'] = dataset_test['form_field44'].fillna(dataset_test['form_field44'].dropna().mode().values[0])
dataset_test['form_field45'] = dataset_test['form_field45'].fillna(dataset_test['form_field45'].dropna().mode().values[0])
dataset_test['form_field46'] = dataset_test['form_field46'].fillna(dataset_test['form_field46'].dropna().mode().values[0])
dataset_test['form_field48'] = dataset_test['form_field48'].fillna(dataset_test['form_field48'].dropna().mode().values[0])
dataset_test['form_field49'] = dataset_test['form_field49'].fillna(dataset_test['form_field49'].dropna().mode().values[0])
dataset_test['form_field50'] = dataset_test['form_field50'].fillna(dataset_test['form_field50'].dropna().mode().values[0])

# %%
##Missing Values: Check where there are missing values and fix them appropriately
total = dataset_test.isnull().sum().sort_values(ascending=False)
percent = (dataset_test.isnull().sum()/dataset_test.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(51)
# Out:
#               Total  Percent
# form_field50      0      0.0
# form_field13      0      0.0
# form_field23      0      0.0
# form_field22      0      0.0
# form_field21      0      0.0
# form_field20      0      0.0
# form_field19      0      0.0
# form_field18      0      0.0
# form_field17      0      0.0
# form_field16      0      0.0
# form_field15      0      0.0
# form_field14      0      0.0
# form_field12      0      0.0
# form_field49      0      0.0
# form_field11      0      0.0
# form_field10      0      0.0
# form_field9       0      0.0
# form_field8       0      0.0
# form_field7       0      0.0
# form_field6       0      0.0
# form_field5       0      0.0
# form_field4       0      0.0
# form_field3       0      0.0
# form_field2       0      0.0
# form_field24      0      0.0
# form_field25      0      0.0
# form_field26      0      0.0
# form_field27      0      0.0
# form_field48      0      0.0
# form_field47      0      0.0
# form_field46      0      0.0
# ...

# %%
##Exploratory Data Analysis: We want to show the power of visualizations
sns.countplot(x= "default_status", data= dataset_train)
plt.show()
#few numbers of people default

# %%
code_numeric = {
'yes': 1, 'no': 0,
'charge': 1, 'lending': 2}
dataset_train = dataset_train.applymap(lambda s: code_numeric.get(s) if s in code_numeric else s)
dataset_test = dataset_test.applymap(lambda s: code_numeric.get(s) if s in code_numeric else s)

#drop the uniques loan id
dataset_train.drop('Applicant_ID', axis = 1, inplace = True)

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56000 entries, 0 to 55999
# Data columns (total 51 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   form_field1     56000 non-null  float64
#  1   form_field2     56000 non-null  float64
#  2   form_field3     56000 non-null  float64
#  3   form_field4     56000 non-null  float64
#  4   form_field5     56000 non-null  float64
#  5   form_field6     56000 non-null  float64
#  6   form_field7     56000 non-null  float64
#  7   form_field8     56000 non-null  float64
#  8   form_field9     56000 non-null  float64
#  9   form_field10    56000 non-null  float64
#  10  form_field11    56000 non-null  float64
#  11  form_field12    56000 non-null  float64
#  12  form_field13    56000 non-null  float64
#  13  form_field14    56000 non-null  int64
#  14  form_field15    56000 non-null  float64
#  15  form_field16    56000 non-null  float64
# ...

# %%
sns.heatmap(dataset_train.corr())
# Out:
# <AxesSubplot:>

# %%
##Separating Target from the feature for training
y = dataset_train['default_status']
X = dataset_train.drop('default_status', axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
##Using Logistic Regression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
ypred = model.predict(X_test)
print(ypred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
evaluation = f1_score(y_test, ypred)
evaluation
# Out:
# 0.043692741367159976

# %%
index = dataset_test.pop('Applicant_ID')

# %%
ypred = model.predict(dataset_test)

# %%
submission = pd.read_csv("file:///Users/mac/Downloads/SampleSubmission_2.csv")
submission
# Out:
#         Applicant_ID  default_status
# 0      Apcnt_1000032               1
# 1      Apcnt_1000048               1
# 2      Apcnt_1000052               1
# 3      Apcnt_1000076               1
# 4      Apcnt_1000080               1
# ...              ...             ...
# 23995   Apcnt_999940               1
# 23996   Apcnt_999956               1
# 23997   Apcnt_999976               1
# 23998   Apcnt_999984               1
# 23999   Apcnt_999992               1
#
# [24000 rows x 2 columns]

# %%
submission.default_status = ypred
submission
# Out:
#         Applicant_ID  default_status
# 0      Apcnt_1000032               0
# 1      Apcnt_1000048               0
# 2      Apcnt_1000052               0
# 3      Apcnt_1000076               0
# 4      Apcnt_1000080               0
# ...              ...             ...
# 23995   Apcnt_999940               0
# 23996   Apcnt_999956               0
# 23997   Apcnt_999976               0
# 23998   Apcnt_999984               0
# 23999   Apcnt_999992               0
#
# [24000 rows x 2 columns]

# %%
submission.to_csv("default_status1.csv",index= False)

# %%
##Using Decision Tree
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
ypred_tree = tree.predict(X_test)
print(ypred_tree)
# Out:
# [0 1 0 ... 0 0 0]

# %%
evaluation = f1_score(y_test, ypred_tree)
evaluation
# Out:
# 0.4518212811771039

# %%
ypred_tree = tree.predict(dataset_test)

# %%
submission.default_status = ypred_tree
submission
# Out:
#         Applicant_ID  default_status
# 0      Apcnt_1000032               1
# 1      Apcnt_1000048               0
# 2      Apcnt_1000052               0
# 3      Apcnt_1000076               1
# 4      Apcnt_1000080               0
# ...              ...             ...
# 23995   Apcnt_999940               1
# 23996   Apcnt_999956               0
# 23997   Apcnt_999976               1
# 23998   Apcnt_999984               1
# 23999   Apcnt_999992               0
#
# [24000 rows x 2 columns]

# %%
submission.to_csv("default_status2.csv",index= False)

# %%
###Using Random Forest Classifier
forest = RandomForestClassifier()

# %%
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
ypred_forest = forest.predict(X_test)
print(ypred_forest)
# Out:
# [0 0 0 ... 0 0 0]

# %%
evaluation = f1_score(y_test, ypred_forest)
evaluation
# Out:
# 0.5117018859350148

# %%
ypred_forest = forest.predict(dataset_test)
